# %% [markdown]
# # TP N°2 - Traitement de données en table
# # Implantation d'Eoliennes en Eure et Loir

# %% [markdown]
# Le département de l’Eure-et-Loir décide de développer son parc éolien à l’horizon 2025.
# Pour cela un bureau de la préfecture est chargé de définir les lieux potentiellement éligibles pour accueillir un futur parc éolien, et il fait appel à vous pour le faire de façon automatique grâce à un script Python.
#
# Pour être éligible, la commune devra avoir moins de 1000 habitants et être située à une altitude supérieure à 200 mètres . Il y aura maximum 8 parcs de créer. Si le nombre de communes éligibles est supérieur à 8, ce seront celles qui ont la plus grande superficie qui seront retenues.
#
# Pour cela, le bureau décide de référencer toutes les communes du département et d’en extraire les communes éligibles. Il dispose d’un fichier au format csv , récupéré sur data.gouv.fr . Malheureusement ce fichier contient toutes communes de la région Centre val de Loire. Et des renseignements inutiles pour la problématique.

# %% [markdown]
# ## 1. Préliminaires

# %% [markdown]
# #### a) Réaliser un fichier CSV à partir de Python

# %% [markdown]
# On considère la fonction `export_fichier_csv` suivante. Exécuter le code et compléter la documentation de la fonction.

# %%
import csv

liste = [{'a':0,'b':2}, {'a':5,'b':6}, {'a':-3,'b':3}]

def export_fichier_csv(nom_fichier, liste_enregistrements, separateur):
    """
    Rôle de la fonction : exporter une liste d'enregistrements en un fichier au format CSV
    param nom_fichier : type str - nom au format CSV qui contient les données exportées
    param liste_enregistrements : type liste de dict. liste des enregistrements à enregistrer dans le fichier CSV créé
    param separateur : type str - séparateur utilisé par le fichier CSV.
    """

    with open(nom_fichier, 'w', newline='', encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile,
                                fieldnames=list(liste_enregistrements[0].keys()),
                                delimiter=separateur)

        # Ecriture de la premiere ligne du fichier CSV avec le nom des descripteurs
        writer.writeheader()

        # Export de tous les enregistrements de la liste
        for enregistrement in liste_enregistrements:
            writer.writerow(enregistrement)

export_fichier_csv('essai.csv',liste,";")
# Youpi le fichier essai.cvs est créé dans le répertoire courant avec les infos de la liste :)

# %% [markdown]
# ### b) Trier une liste de dictionnaires selon une clé

# %% [markdown]
# Si `liste = [5,1,7,3]`, pour trier la `liste`, on peut utiliser la méthode `liste.sort()`.

# %%
liste = [5,1,7,3]

sorted(liste)
print(liste)
# sorted(liste) renvoie une liste triée mais ne modifie la liste initiale.

liste.sort()
print(liste)
#liste est modifiée et se retrouvée triée

# pour trier par ordre décroissant, on peut utiliser l'option reverse comme ci-dessous :
liste.sort(reverse = True)
print(liste)
# Out:
# [5, 1, 7, 3]
# [1, 3, 5, 7]
# [7, 5, 3, 1]

# %% [markdown]
# Mais comment trier `liste = [('Bob', 25),('Alice', 17),('Corale', 15)]` ?

# %%
liste = [('Bob', 25),('Carole', 15), ('Alice', 17)]

# Pour trier cette liste selon le premier élément de chaque tuple
def choix_param_tri(elt):
    return elt[0]

liste.sort(key = choix_param_tri) 
# key reçoit une fonction, cette fonction reçoit en paramètre un élément de la liste et retourne le critère de tri 
# ici elt[0]
print(liste)

# Autre codage possible plus concis
liste = [('Bob', 25), ('Carole', 15), ('Alice', 17)]
liste.sort(key = lambda elt:elt[0])
# lambda est une fonction où elt est un paramètre et elt[0] est la valeur retournée
print(liste)
# Out:
# [('Alice', 17), ('Bob', 25), ('Carole', 15)]
# [('Alice', 17), ('Bob', 25), ('Carole', 15)]

# %% [markdown]
# <div class="alert alert-info">
#
# <strong class='fa fa-cogs' style="color: darkorange"> A faire </strong>
# </div>

# %%
liste = [('Bob', 25), ('Carole', 15), ('Alice', 17)]
# Proposer un code permet de trier liste par ordre décroissant, en utilisant comme critère de tri 
# le deuxième elt de chaque tuple

liste.sort(key = lambda elt: elt[1], reverse = True)
print(liste)
# Out:
# [('Bob', 25), ('Alice', 17), ('Carole', 15)]

# %%
liste = [{'a':0,'b':2},{'a':5,'b':6},{'a':-3,'b':3}]
# Proposer un code permettant de trier la liste par ordre croissant en utilisant comme critère de tri
# la valeur associée à la clé 'b'.

liste.sort(key = lambda elt: elt['b'])
print(liste)
# Out:
# [{'a': 0, 'b': 2}, {'a': -3, 'b': 3}, {'a': 5, 'b': 6}]

# %% [markdown]
# ## 2. Retour au projet

# %% [markdown]
# L'ensemble des communes de la région Centre Val de Loire, sont répertoriées, avec leurs caractéristiques dans le fichier `communes_2016.csv`.

# %% [markdown]
# <div class="alert alert-info">
#
# <strong class='fa fa-cogs' style="color: darkorange"> Importation des données </strong>
#
# 1. On souhaite importer les données de la table sur la forme d'une liste de dictionnaires.<br/>
# Ces informations seront stockées dans une liste appelée `liste_communes`.
#
# 2. Compléter le code pour afficher la liste des descripteurs.
# </div>

# %%
# Code pour importer les données du fichier CSV
import csv

def charger_csv_dict(nom_fichier):
    """Fonction qui permet d'importer les données du fichier csv sous forme de liste de listes 
    param nom_fichier : nom du fichier à importer - type str
    return liste_dicos : liste de dictionnaires
    """

    liste_dicos = []  # table à retourner

    # import du fichier
    with open(nom_fichier, "r", newline="", encoding="utf-8") as fichier_csv:
        lecteur_csv = csv.DictReader(fichier_csv, delimiter=";") #le changement est ici par rapport à la structure précédente
        for enreg in lecteur_csv:  # boucle de parcours des enregistrements
            # enreg est une liste de str contenant chaque ligne de l ' enregistrement
            liste_dicos.append(dict(enreg))
    return liste_dicos

liste_communes = charger_csv_dict('communes_2016.csv')

# Code pour afficher la liste des descripteurs
print("l'ensemble des descripteurs est :")
for cle in liste_communes[0].keys():
    print(cle)
# Out:
# l'ensemble des descripteurs est :
# Geo Point
# Geo Shape
# ID
# Code Commune
# Code Insee
# Commune
# X Chf Lieu
# Y Chf Lieu
# X Centroid
# Y Centroid
# Altitude Moyenne
# Superficie
# Population
# Code Canton
# Code Arrondissement
# Code Département
# Année
# Région
# Département
# Statut
# Code Région
# Code EPCI

# %% [markdown]
# <div class="alert alert-info">
#
# <strong class='fa fa-cogs' style="color: darkorange"> Sélection des données </strong>
#
# 1. Avant de s’intéresser à proprement parler au problème éolien, il faut modifier les données pour ne garder que les champs pertinents évoqués dans la présentation du projet.<br/>
# Ecrire le code de la fonction `selection_descripteurs` suivante.
# 2. Ecrire le script d'une fonction `selection_departement` qui reçoit en paramètres une liste d'enregistrements et un département et qui retourne la liste d'enregistrements avec uniquement les enregistrements du département entré en paramètre.
# </div>

# %%
from pprint import pprint

def selection_descripteurs(liste_enregistrements, liste_champs):
    """
    param liste_enregistrements: liste de dictionnaires (liste des enregistrements d'une table)
    param liste_champs: liste de str correspon à la liste des descripteurs à conserver
    return: liste_enregistrements avec les clés des descripteurs inutiles supprimés.
    """
    liste_descripteurs = list(liste_enregistrements[0].keys())
    for enregistrement in liste_enregistrements:
        for cle in liste_descripteurs:
            if cle not in liste_champs:
                del(enregistrement[cle])
    return liste_enregistrements


def selection_departement(liste_enregistrements, departement):
    """
    Fonction qui retourne la liste liste_enregistrements avec uniquement les enregistrements de département donné
    en paramètre.
    param liste_communes: liste de dictionnaires (liste des enregistrements d'une table)
    param departement: chaine de caractères : numéro du département à sélectionner
    return: liste_enregistrements modifiée.
    """
    liste_communes_departement = []
    for enregistrement in liste_enregistrements:
        if enregistrement['Code Département'] == departement:
            liste_communes_departement.append(enregistrement)
    return liste_communes_departement
    

# afficher le premier enregistrement pour vérifier le bon fonctionnement de la première fonction
liste_communes = charger_csv_dict('communes_2016.csv')
selection_descripteurs(liste_communes,['ID', 'Code Département'])
pprint(liste_communes[0])

# vérifier le bon fonctionnement de la deuxième fonction.
#liste_communes = charger_csv_dict('communes_2016.csv')
liste_departement = selection_departement(liste_communes,'28')
pprint(liste_departement)
# Out:
# {'Code Département': '36', 'ID': 'COMMUNE00000000000030834'}
# [{'Code Département': '28', 'ID': 'COMMUNE00000000000030712'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012611'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005889'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014902'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012731'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023707'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031724'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000034204'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011597'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020518'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031963'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000015083'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029479'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011535'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011895'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030265'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028810'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014327'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014015'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000021726'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000009862'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001491'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005349'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000004990'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002261'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017381'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012077'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006397'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028262'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001966'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002600'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001237'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011166'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016200'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000003628'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020756'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016678'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014457'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020540'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020492'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000034031'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000033789'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000027171'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000021360'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005856'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016594'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000009114'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000015643'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012513'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002295'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005381'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000018131'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005223'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014245'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023952'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023249'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000008871'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000018404'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000015442'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028120'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014592'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000004948'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019524'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000018973'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000034479'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023734'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000035578'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023171'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000010308'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000015046'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000027652'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017210'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000033688'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001903'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000013121'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000034232'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012293'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000025419'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017781'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000025554'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000004010'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001724'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030009'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012976'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000018236'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000018769'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002841'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000027876'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000034454'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030326'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001461'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012248'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030777'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000018358'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012502'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006990'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000007209'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023716'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002944'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000010522'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019809'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000013690'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000008864'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000024700'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000035662'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000219'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000004913'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011906'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000003962'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031019'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031262'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030652'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002129'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030562'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005821'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019721'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011675'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014029'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023818'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000009075'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000025107'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000015897'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022079'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016175'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022738'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022784'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000032241'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019889'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016955'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017553'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001607'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030199'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016128'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000700'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012332'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012486'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005161'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022105'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005484'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006082'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023395'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023003'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022400'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023453'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000026395'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002377'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000035517'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000035063'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011465'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031218'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022820'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020195'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000007237'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006200'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001230'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000027543'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012874'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000025515'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020362'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029636'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020411'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000024410'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028434'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019945'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017755'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023994'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000003046'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020392'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014280'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017652'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031518'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020488'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022956'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000009320'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000026611'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000010479'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000015639'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000010246'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000009990'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006037'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023089'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029335'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000007488'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028359'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000024626'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001950'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000013646'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019753'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005219'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030215'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000033768'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028329'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000034209'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017384'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028643'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000027162'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006714'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031835'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000033273'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000007786'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030081'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031298'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022025'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000026651'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020663'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006035'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016893'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005166'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000034546'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000015525'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011723'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019851'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000024784'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020339'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000010527'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019772'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031058'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000033732'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012200'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028028'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000009689'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000018671'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000009460'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029804'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000004947'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000007210'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000008188'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000004755'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000032773'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011846'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022896'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000015891'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031752'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000024232'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016456'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000026531'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011523'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017056'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020638'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031360'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002417'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000003135'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030991'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006139'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012498'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000013243'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000035697'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022408'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005027'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014885'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022083'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029006'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012478'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022375'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000367'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020295'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020604'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000004019'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000007197'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002386'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001540'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017006'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000015627'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022593'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002893'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000024606'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023230'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000008762'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012777'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000032240'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016346'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011531'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014634'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011067'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028911'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022611'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028455'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000589'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000025550'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000032025'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002584'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002154'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029697'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031608'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002381'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000034658'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017354'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000007090'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020234'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016179'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006353'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000013275'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006601'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016358'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000862'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029914'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000033151'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000004914'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000008030'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019029'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000034037'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030419'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000021872'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001725'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031057'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000032591'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017497'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005004'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000035533'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000032461'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000032803'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029346'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000025664'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000024551'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029091'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020397'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000007741'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002275'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000008120'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019501'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000001757'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000007813'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000003581'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000003797'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000021929'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023997'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017904'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023294'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000416'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000027961'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000020093'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000613'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000028225'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000676'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005492'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000018450'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031076'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030471'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019877'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011223'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000009425'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031303'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000033462'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000013004'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000026981'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000015444'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000024596'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000014133'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000019939'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006302'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000975'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000010729'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000011435'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000035178'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000032093'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000002057'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031927'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000013891'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000004256'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000009360'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000008541'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000012771'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000005184'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000025179'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031342'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022252'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000021335'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029231'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000023622'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000003288'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000010408'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000027526'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000025278'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000016446'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000030885'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000031049'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000017544'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000034294'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000027199'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000018416'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000024268'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022833'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000087'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000010324'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000000211'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000018107'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000022126'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000008450'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000033642'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000006485'},
#  {'Code Département': '28', 'ID': 'COMMUNE00000000000029139'}]

# %% [markdown]
# <div class="alert alert-info">
#
# <strong class='fa fa-cogs' style="color: darkorange"> Choix des communes candidates </strong>
#
# Ecrire le script d'une fonction `selection_criteres` qui reçoit en paramètre une liste d'enregistrements et qui renvoie la liste des enregistrements répondant aux critères pour installer des éoliennes.
# </div>

# %%
def selection_criteres(liste_enregistrements):
    liste_criteres = []
    for enregistrement in liste_enregistrements:
        if (int(enregistrement['Altitude Moyenne']) > 200) and (float(enregistrement['Population']) < 1000):
            liste_criteres.append(enregistrement)
    return liste_criteres

# %% [markdown]
# <div class="alert alert-info">
#
# <strong class='fa fa-cogs' style="color: darkorange"> Edition des communes retenues </strong>
#
# 1. Donner le script d'un algorithme permettant de déterminer les communes retenues pour l'implantation des éoliennes.
# 2. Enregistrer ces communes et leurs caractéristiques retenues dans un fichier `communes_retenues.csv`.
# </div>

# %%
# Question 1
# Script pour trouver les communes retenues. Il faut sélectionner les 8 qui ont la plus grande superficie

def tri_communes_superficie(liste_enregistrements):
    """
    Fonction qui reçoit une liste de communes (liste de dictionnaires) et qui retourne la liste des 8 communes ayant la plus grande superficie
    """
    if len(liste_enregistrements) <=8:
        return liste_enregistrements
    else:
        liste_enregistrements.sort(key = lambda commune:int(commune['Superficie']), reverse = True)
        liste_communes_retenues = []
        for i in range(8):
            liste_communes_retenues.append(liste_enregistrements[i])
        return liste_communes_retenues
        # On peut remplacer la boucle par du slicing en faisant return liste_communes[0:8]

        
        
# On donne ici la liste des descripteurs à retenir
liste_descripteurs = ['Code Insee', 'Commune', 'Altitude Moyenne', 'Superficie', 'Population', 'Code Département']
liste_communes = charger_csv_dict('communes_2016.csv')
selection_descripteurs(liste_communes, liste_descripteurs)
# il n'est pas nécessaire de faire une affectation car liste_communes est modifiée

liste_communes = selection_departement(liste_communes, '28')
liste_criteres = selection_criteres(liste_communes)

#pprint(liste_criteres)
# il n'est pas nécessaire de faire une affectation car liste_communes est modifiée
liste_communes_retenues = tri_communes_superficie(liste_criteres)

# Question 2 : enregistrement dans un fichier csv
export_fichier_csv('communes_retenues.csv',liste_communes_retenues,";")
